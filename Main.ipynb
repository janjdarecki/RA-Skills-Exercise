# %%
import pandas as pd
import numpy as np
from glob import glob
from pathlib import Path

# %% [markdown]
# ## Load

# %%
# Load reference data
ref = pd.read_csv("data/congress_members_with_parties.csv")

# Load and append election files
files = sorted(glob("data/congressional_elections_*.csv"))

dfs = []
for f in files:
    try:
        df = pd.read_csv(f)
        if df.empty:
            continue
        df = df.assign(year=int(Path(f).stem.split("_")[-1]))
        dfs.append(df)
    except pd.errors.EmptyDataError:
        continue

elecs = pd.concat(dfs, ignore_index=True) if dfs else pd.DataFrame()
elecs = elecs.drop(columns='status') # unreliable column

# %% [markdown]
# ## Explore datasets

# %% [markdown]
# ### Congress members dataset

# %% [markdown]
# - Duplicates explained by switches between chambers and gaps between stints
# - Most recent title applied retroactively

# %%
# Check for duplicates
ref[ref.duplicated(subset=['name'], keep=False)].head(6)

# duplicates happen for members that switch from house to senate or have a gap in congress
# also seems the senator title is applied retroactively
# Out:
#                 name first_name    last_name           title         state  \
# 0      Abdnor, James      James       Abdnor         Senator  South Dakota
# 1      Abdnor, James      James       Abdnor         Senator  South Dakota
# 2  Abercrombie, Neil       Neil  Abercrombie  Representative        Hawaii
# 3  Abercrombie, Neil       Neil  Abercrombie  Representative        Hawaii
# 4    Abourezk, James      James     Abourezk         Senator  South Dakota
# 5    Abourezk, James      James     Abourezk         Senator  South Dakota
#
#   house_or_senate  start_year end_year       party
# 0          Senate        1981     1987  Republican
# 1           House        1973     1981  Republican
# 2           House        1985     1987  Democratic
# 3           House        1991     2011  Democratic
# 4          Senate        1973     1979  Democratic
# 5           House        1971     1973  Democratic

# %%
ref_1 = ref.drop_duplicates(subset=['name', 'house_or_senate']) # drop members with gaps in the same chamber
ref_1 = ref_1.sort_values(by=['name', 'start_year']).reset_index(drop=True) # sort
ref_2 = ref_1[ref_1.duplicated(subset=['name'], keep='last')] # get names with stints in both chambers, take their first stint
ref_2.house_or_senate.value_counts()

# there are 174 members with a switch from house to senate and 1 vice versa
# Out:
# house_or_senate
# House     174
# Senate      1
# Name: count, dtype: int64

# %%
ref_2[ref_2.house_or_senate=='Senate']
# Out:
#                 name first_name last_name           title    state  \
# 1999  Pepper, Claude     Claude    Pepper  Representative  Florida
#
#      house_or_senate  start_year end_year       party
# 1999          Senate        1935     1951  Democratic

# %%
ref[ref.name=='Pepper, Claude']

# most recent title is applied retroactively
# Out:
#                 name first_name last_name           title    state  \
# 2074  Pepper, Claude     Claude    Pepper  Representative  Florida
# 2075  Pepper, Claude     Claude    Pepper  Representative  Florida
#
#      house_or_senate  start_year end_year       party
# 2074          Senate        1935     1951  Democratic
# 2075           House        1963     1991  Democratic

# %% [markdown]
# ### Elections dataset

# %% [markdown]
# - Candidate duplicates explained via special elections
# - Name duplicates down to name commonalitity; does not hinder name-matching

# %%
elecs[elecs.duplicated(subset=['url', 'year'], keep=False)].sort_values(by='name')

# unusual but possible via special elections
# Out:
#                 name                              url        party  year  \
# 22962    Adam Schiff      /candidate/9489/adam-schiff   Democratic  2024
# 22960    Adam Schiff      /candidate/9489/adam-schiff   Democratic  2024
# 11349    Albio Sires     /candidate/22510/albio-sires   Democratic  2006
# 11868    Albio Sires     /candidate/22510/albio-sires   Democratic  2006
# 21701   Alex Padilla    /candidate/59742/alex-padilla   Democratic  2022
# ...              ...                              ...          ...   ...
# 23002     Vince Fong     /candidate/169357/vince-fong   Republican  2024
# 12628     Wally Pang      /candidate/69867/wally-pang  Independent  2008
# 12623     Wally Pang      /candidate/69867/wally-pang  Independent  2008
# 22079  William Henry  /candidate/193495/william-henry  Libertarian  2022
# 22078  William Henry  /candidate/193495/william-henry  Libertarian  2022
#
#             election
# 22962  congressional
# 22960  congressional
# 11349  congressional
# 11868  congressional
# 21701  congressional
# ...              ...
# 23002  congressional
# 12628  congressional
# 12623  congressional
# 22079  congressional
# 22078  congressional
#
# [250 rows x 5 columns]

# %%
cand = elecs.drop_duplicates(subset=['url']) # unique candidates
cand[cand.duplicated(subset=['name'], keep=False)].sort_values(by='name')

# these are common names, likely not due to duplicated webpages
# Out:
#                    name                                 url  \
# 9653         Adam Smith         /candidate/35178/adam-smith
# 4491         Adam Smith           /candidate/845/adam-smith
# 22943       Alan Aversa       /candidate/216960/alan-aversa
# 15184       Alan Aversa       /candidate/143566/alan-aversa
# 10017    Angela Lariscy     /candidate/43168/angela-lariscy
# ...                 ...                                 ...
# 11629     William Smith      /candidate/65713/william-smith
# 693    William Stephens    /candidate/2008/william-stephens
# 12645  William Stephens  /candidate/102893/william-stephens
# 7365     William Walker     /candidate/47999/william-walker
# 1381     William Walker     /candidate/15368/william-walker
#
#                        party  year       election
# 9653              Democratic  2004  congressional
# 4491              Democratic  1996  congressional
# 22943            Green Party  2024  congressional
# 15184  Nominated by Petition  2012  congressional
# 10017                    NaN  2004  congressional
# ...                      ...   ...            ...
# 11629            Independent  2006  congressional
# 693                 Write-In  1992  congressional
# 12645             Republican  2008  congressional
# 7365             Libertarian  2000  congressional
# 1381             Libertarian  1992  congressional
#
# [454 rows x 5 columns]

# %%
cand.party.value_counts().iloc[:10]
# Out:
# party
# Democratic              3804
# Republican              3609
# Libertarian             1890
# Independent             1034
# Write-In                 399
# Green Party              378
# Natural Law Party        275
# No Party Affiliation     191
# Constitution             152
# Reform                   139
# Name: count, dtype: int64

# %% [markdown]
# ## Strategy and assumptions

# %% [markdown]
# The matching strategy iterates over records in the reference dataset and can be summarised in the following steps:
#
# 1. Find (in the elections dataset) records with the same surname

# %% [markdown]
# ## Matching

# %%
from main import namematch

mat, unmat = namematch(ref, elecs)

mat.to_csv("matched.csv")
unmat.to_csv("unmatched.csv")
# Out:
# [fail-lastname] Mikva, Abner J.: no candidates with last name 'Mikva'
# [fail-lastname] Ribicoff, Abraham A.: no candidates with last name 'Ribicoff'
# [fail-lastname] Kazen, Abraham, Jr.: no candidates with last name 'Kazen'
# [ambiguous] Smith, Adam: multiple candidates remain after deterministic filters:
#       name                         url
# Adam Smith /candidate/35178/adam-smith
# Adam Smith   /candidate/845/adam-smith
# [fail-firstname] Benjamin, Adam, Jr.: no candidates with last name 'Benjamin' and first name 'Adam'
# [fail-firstname] Stevenson, Adlai E., III: no candidates with last name 'Stevenson' and first name 'Adlai'
# [fail-lastname] Ullman, Al: no candidates with last name 'Ullman'
# [fail-lastname] Bible, Alan: no candidates with last name 'Bible'
# [fail-lastname] Cranston, Alan: no candidates with last name 'Cranston'
# [fail-lastname] Steelman, Alan: no candidates with last name 'Steelman'
# [fail-firstname] Dixon, Alan J.: no candidates with last name 'Dixon' and first name 'Alan'
# [fail-firstname] Simpson, Alan K.: no candidates with last name 'Simpson' and first name 'Alan'
# [fail-lastname] Quie, Albert H.: no candidates with last name 'Quie'
# [fail-firstname] Johnson, Albert W.: no candidates with last name 'Johnson' and first name 'Albert'
# [only-surname] Mooney, Alexander X.: one candidate with last name 'Mooney' but firstname mismatch
#        name                           url
# Alex Mooney /candidate/145943/alex-mooney
# [fail-firstname] Howe, Allan: no candidates with last name 'Howe' and first name 'Allan'
# [fail-lastname] Ertel, Allen E.: no candidates with last name 'Ertel'
# [fail-firstname] Bell, Alphonzo: no candidates with last name 'Bell' and first name 'Alphonzo'
# [fail-lastname] Waldon, Alton R., Jr.: no candidates with last name 'Waldon'
# [fail-lastname] Baldus, Alvin J.: no candidates with last name 'Baldus'
# [fail-lastname] Nelsen, Ancher: no candidates with last name 'Nelsen'
# [only-surname] Maguire, Andrew: one candidate with last name 'Maguire' but firstname mismatch
#         name                         url
# Bill Maguire /candidate/679/bill-maguire
# [fail-firstname] Young, Andrew: no candidates with last name 'Young' and first name 'Andy, Drew, Andrew'
# [fail-lastname] Hinshaw, Andrew J.: no candidates with last name 'Hinshaw'
# [fail-firstname] Ireland, Andrew P.: no candidates with last name 'Ireland' and first name 'Andy, Drew, Andrew'
# [ambiguous] Kim, Andy: multiple candidates remain after deterministic filters:
#       name                        url
#   Andy Kim /candidate/179640/andy-kim
# Andrew Kim /candidate/9773/andrew-kim
# [fail-lastname] Roncallo, Angelo D.: no candidates with last name 'Roncallo'
# [only-surname] Acevedo-Vila, Anibal: one candidate with last name 'Acevedo-Vila' but firstname mismatch
#               name                                 url
# Mary Alice Acevedo /candidate/22335/mary-alice-acevedo
# [fail-lastname] Coelho, Anthony Lee: no candidates with last name 'Coelho'
# [only-surname] Won Pat, Antonio B.: one candidate with last name 'Won Pat' but firstname mismatch
#           name                              url
# Judith Won Pat /candidate/209780/judith-won-pat
# [fail-lastname] Stangeland, Arlan: no candidates with last name 'Stangeland'
# [fail-lastname] Erdahl, Arlen: no candidates with last name 'Erdahl'
# [fail-firstname] Moody, Ashley: no candidates with last name 'Moody' and first name 'Ashley'
# [fail-firstname] Hawkins, Augustus F.: no candidates with last name 'Hawkins' and first name 'Gus, Augustus'
# [fail-lastname] Sisk, B. F.: no candidates with last name 'Sisk'
# [fail-lastname] Corrada, Baltasar: no candidates with last name 'Corrada'
# [fail-firstname] Jordan, Barbara: no candidates with last name 'Jordan' and first name 'Barbara'
# [fail-lastname] Conable, Barber B., Jr.: no candidates with last name 'Conable'
# [only-surname] Goldwater, Barry: one candidate with last name 'Goldwater' but firstname mismatch
#              name                               url
# Michael Goldwater /candidate/1455/michael-goldwater
# [only-surname] Goldwater, Barry, Jr.: one candidate with last name 'Goldwater' but firstname mismatch
#              name                               url
# Michael Goldwater /candidate/1455/michael-goldwater
# [fail-lastname] Abzug, Bella S.: no candidates with last name 'Abzug'
# [fail-firstname] Blackburn, Ben: no candidates with last name 'Blackburn' and first name 'Benjamin, Ben'
# [ambiguous] Jones, Ben: multiple candidates remain after deterministic filters:
#      name                        url
# Ben Jones /candidate/22025/ben-jones
# Ben Jones /candidate/50904/ben-jones
# [fail-firstname] Rosenthal, Benjamin S.: no candidates with last name 'Rosenthal' and first name 'Benjamin, Ben'
# [fail-firstname] Stewart, Bennett McVey: no candidates with last name 'Stewart' and first name 'Bennett'
# [fail-firstname] Bedell, Berkley W.: no candidates with last name 'Bedell' and first name 'Berkley'
# [fail-firstname] Dwyer, Bernard J.: no candidates with last name 'Dwyer' and first name 'Bernie, Bennie, Bernard'
# [fail-lastname] Podell, Bertram L.: no candidates with last name 'Podell'
# [fail-firstname] Anthony, Beryl, Jr.: no candidates with last name 'Anthony' and first name 'Beryl'
# [fail-firstname] Byron, Beverly B.: no candidates with last name 'Byron' and first name 'Beverly'
# [ambiguous] Baker, Bill: multiple candidates remain after deterministic filters:
#          name                            url
# William Baker /candidate/26738/william-baker
# William Baker   /candidate/315/william-baker
# [ambiguous] Brock, Bill: multiple candidates remain after deterministic filters:
#                  name                                    url
# William Emerson Brock /candidate/22195/william-emerson-brock
#            Bill Brock            /candidate/25360/bill-brock
# [fail-lastname] Frenzel, Bill: no candidates with last name 'Frenzel'
# [fail-lastname] Gunter, Bill: no candidates with last name 'Gunter'
# [fail-lastname] Hendon, Bill: no candidates with last name 'Hendon'
# [ambiguous] Johnson, Bill: multiple candidates remain after deterministic filters:
#         name                            url
# Bill Johnson /candidate/120649/bill-johnson
# Bill Johnson  /candidate/21981/bill-johnson
# [only-surname] Lowery, Bill: one candidate with last name 'Lowery' but firstname mismatch
#        name                           url
# Amir Lowery /candidate/195447/amir-lowery
# [fail-firstname] Nichols, Bill: no candidates with last name 'Nichols' and first name 'Bill, William'
# [fail-lastname] Schuette, Bill: no candidates with last name 'Schuette'
# [fail-firstname] Burlison, Bill D.: no candidates with last name 'Burlison' and first name 'Bill, William'
# [ambiguous] Brewster, Bill K.: multiple candidates remain after deterministic filters:
#               name                                url
# Bill Brewster, Jr. /candidate/188524/bill-brewster-jr
#      Bill Brewster     /candidate/27029/bill-brewster
# [fail-lastname] Chappell, Bill, Jr.: no candidates with last name 'Chappell'
# [ambiguous] Long, Billy: multiple candidates remain after deterministic filters:
#                        name                                        url
#                  Billy Long               /candidate/123401/billy-long
# William Alexander Long, Jr. /candidate/22272/william-alexander-long-jr
# [fail-firstname] Evans, Billy Lee: no candidates with last name 'Evans' and first name 'Billy, William'
# [only-surname] Bayh, Birch: one candidate with last name 'Bayh' but firstname mismatch
#      name                        url
# Evan Bayh /candidate/22418/evan-bayh
# [only-surname] Ginn, Bo: one candidate with last name 'Ginn' but firstname mismatch
#        name                           url
# Justin Ginn /candidate/220077/justin-ginn
# [only-surname] Bergland, Bob: one candidate with last name 'Bergland' but firstname mismatch
#           name                             url
# Craig Bergland /candidate/68332/craig-bergland
# [ambiguous] Carr, Bob: multiple candidates remain after deterministic filters:
#     name                        url
# Bob Carr /candidate/126490/bob-carr
# Bob Carr /candidate/191579/bob-carr
# [only-surname] Eckhardt, Bob: one candidate with last name 'Eckhardt' but firstname mismatch
#          name                            url
# Kurt Eckhardt /candidate/33916/kurt-eckhardt
# [fail-firstname] Graham, Bob: no candidates with last name 'Graham' and first name 'Bob, Robert'
# [ambiguous] Smith, Bob: multiple candidates remain after deterministic filters:
#         name                         url
#    Bob Smith  /candidate/53322/bob-smith
#    Bob Smith  /candidate/67708/bob-smith
# Robert Smith /candidate/909/robert-smith
# [fail-lastname] Traxler, Bob: no candidates with last name 'Traxler'
# [only-surname] Whittaker, Bob: one candidate with last name 'Whittaker' but firstname mismatch
#          name                        url
# Jed Whittaker /candidate/2/jed-whittaker
# [fail-lastname] Fiedler, Bobbi: no candidates with last name 'Fiedler'
# [fail-firstname] Donnelly, Brian J.: no candidates with last name 'Donnelly' and first name 'Brian'
# [fail-firstname] Adams, Brock: no candidates with last name 'Adams' and first name 'Brock'
# [fail-firstname] Morrison, Bruce A.: no candidates with last name 'Morrison' and first name 'Bruce'
# [fail-lastname] Caputo, Bruce F.: no candidates with last name 'Caputo'
# [fail-firstname] Shuster, Bud: no candidates with last name 'Shuster' and first name 'William, Bud'
# [fail-lastname] MacKay, Buddy: no candidates with last name 'MacKay'
# [only-surname] Roemer, Buddy: one candidate with last name 'Roemer' but firstname mismatch
#           name                             url
# Timothy Roemer /candidate/26852/timothy-roemer
# [fail-lastname] Talcott, Burt L.: no candidates with last name 'Talcott'
# [only-surname] Albert, Carl: one candidate with last name 'Albert' but firstname mismatch
#               name                                 url
# Jack Albert Rogers /candidate/25937/jack-albert-rogers
# [fail-firstname] Perkins, Carl C.: no candidates with last name 'Perkins' and first name 'Carl'
# [fail-lastname] Pursell, Carl D.: no candidates with last name 'Pursell'
# [fail-firstname] Perkins, Carl Dewey: no candidates with last name 'Perkins' and first name 'Carl'
# [fail-firstname] Curtis, Carl T.: no candidates with last name 'Curtis' and first name 'Carl'
# [fail-firstname] King, Carleton J.: no candidates with last name 'King' and first name 'Carleton'
# [ambiguous] Miller, Carol D.: multiple candidates remain after deterministic filters:
#         name                           url
# Carol Miller /candidate/16399/carol-miller
# Carol Miller /candidate/52123/carol-miller
# [fail-firstname] Campbell, Carroll A., Jr.: no candidates with last name 'Campbell' and first name 'Carroll'
# [fail-firstname] Hubbard, Carroll, Jr.: no candidates with last name 'Hubbard' and first name 'Carroll'
# [fail-firstname] Goodwin, Carte Patrick: no candidates with last name 'Goodwin' and first name 'Carte'
# [fail-firstname] Long, Cathy (Mrs. Gillis): no candidates with last name 'Long' and first name 'Cathy'
# [fail-lastname] Heftel, Cecil: no candidates with last name 'Heftel'
# [fail-lastname] Wylie, Chalmers P.: no candidates with last name 'Wylie'
# [fail-lastname] Hatcher, Charles: no candidates with last name 'Hatcher'
# [fail-lastname] Luken, Charles: no candidates with last name 'Luken'
# [fail-lastname] Thone, Charles: no candidates with last name 'Thone'
# [ambiguous] Wilson, Charles: multiple candidates remain after deterministic filters:
#                name                                url
# Charlie Wilson, Jr. /candidate/10092/charlie-wilson-jr
#      Charles Wilson    /candidate/15404/charles-wilson
#      Charles Wilson    /candidate/27078/charles-wilson
# [fail-firstname] Hayes, Charles A.: no candidates with last name 'Hayes' and first name 'Charlie, Charles, Chuck'
# [fail-firstname] Mosher, Charles A.: no candidates with last name 'Mosher' and first name 'Charlie, Charles, Chuck'
# [fail-lastname] Vanik, Charles A.: no candidates with last name 'Vanik'
# [ambiguous] Wilson, Charles A.: multiple candidates remain after deterministic filters:
#                name                                url
# Charlie Wilson, Jr. /candidate/10092/charlie-wilson-jr
#      Charles Wilson    /candidate/15404/charles-wilson
#      Charles Wilson    /candidate/27078/charles-wilson
# [fail-lastname] Diggs, Charles C., Jr.: no candidates with last name 'Diggs'
# [fail-firstname] Bennett, Charles E.: no candidates with last name 'Bennett' and first name 'Charlie, Charles, Chuck'
# [only-surname] Chamberlain, Charles E.: one candidate with last name 'Chamberlain' but firstname mismatch
#            name                              url
# Don Chamberlain /candidate/27598/don-chamberlain
# [fail-firstname] Wiggins, Charles E.: no candidates with last name 'Wiggins' and first name 'Charlie, Charles, Chuck'
# [ambiguous] Bass, Charles F.: multiple candidates remain after deterministic filters:
#         name                           url
# Charlie Bass /candidate/22216/charlie-bass
# Charles Bass /candidate/68349/charles-bass
# [fail-lastname] Percy, Charles H.: no candidates with last name 'Percy'
# [ambiguous] Wilson, Charles H.: multiple candidates remain after deterministic filters:
#                name                                url
# Charlie Wilson, Jr. /candidate/10092/charlie-wilson-jr
#      Charles Wilson    /candidate/15404/charles-wilson
#      Charles Wilson    /candidate/27078/charles-wilson
# [fail-firstname] Carney, Charles J.: no candidates with last name 'Carney' and first name 'Charlie, Charles, Chuck'
# [fail-firstname] Teague, Charles M.: no candidates with last name 'Teague' and first name 'Charlie, Charles, Chuck'
# [only-surname] Mathias, Charles McC., Jr.: one candidate with last name 'Mathias' but firstname mismatch
#                   name                                     url
# Daniel Nielsen Mathias /candidate/38875/daniel-nielsen-mathias
# [fail-lastname] Whitley, Charles O., Sr.: no candidates with last name 'Whitley'
# [fail-lastname] Gubser, Charles S.: no candidates with last name 'Gubser'
# [only-surname] Sandman, Charles W., Jr.: one candidate with last name 'Sandman' but firstname mismatch
#         name                            url
# Skip Sandman /candidate/152791/skip-sandman
# [fail-firstname] Whalen, Charles W., Jr.: no candidates with last name 'Whalen' and first name 'Charlie, Charles, Chuck'
# [fail-lastname] Pashayan, Charles, Jr.: no candidates with last name 'Pashayan'
# [only-surname] Atkins, Chester G.: one candidate with last name 'Atkins' but firstname mismatch
#        name                           url
# Joey Atkins /candidate/217121/joey-atkins
# [fail-lastname] Holifield, Chet: no candidates with last name 'Holifield'
# [fail-firstname] Hecht, Chic: no candidates with last name 'Hecht' and first name 'Chic'
# [ambiguous] Collins, Chris: multiple candidates remain after deterministic filters:
#                name                                  url
#       Chris Collins      /candidate/139770/chris-collins
# Christopher Collins /candidate/23039/christopher-collins
# [ambiguous] Cox, Christopher: multiple candidates remain after deterministic filters:
#            name                              url
#       Chris Cox      /candidate/127051/chris-cox
# Christopher Cox /candidate/26773/christopher-cox
# [fail-firstname] Bond, Christopher S.: no candidates with last name 'Bond' and first name 'Christopher, Chris'
# [fail-firstname] Douglas, Chuck: no candidates with last name 'Douglas' and first name 'Charles, Chuck'
# [only-surname] Pell, Claiborne: one candidate with last name 'Pell' but firstname mismatch
#       name                         url
# Lewis Pell /candidate/43157/lewis-pell
# [fail-lastname] Burgener, Clair W.: no candidates with last name 'Burgener'
# [fail-firstname] Long, Clarence D.: no candidates with last name 'Long' and first name 'Clarence'
# [fail-firstname] Miller, Clarence E.: no candidates with last name 'Miller' and first name 'Clarence'
# [fail-firstname] Brown, Clarence, Jr.: no candidates with last name 'Brown' and first name 'Clarence'
# [fail-firstname] Harris, Claude: no candidates with last name 'Harris' and first name 'Claud, Claude'
# [only-surname] Pepper, Claude: one candidate with last name 'Pepper' but firstname mismatch
#                name                                  url
# Gregory Dale Pepper /candidate/21840/gregory-dale-pepper
# [fail-firstname] Leach, Claude (Buddy), Jr.: no candidates with last name 'Leach' and first name 'Claud, Claude'
# [fail-firstname] Schneider, Claudine: no candidates with last name 'Schneider' and first name 'Claudine'
# [only-surname] McSpadden, Clem Rogers: one candidate with last name 'McSpadden' but firstname mismatch
#           name                             url
# Mark McSpadden /candidate/29578/mark-mcspadden
# [fail-lastname] Zablocki, Clement J.: no candidates with last name 'Zablocki'
# [fail-firstname] Benedict, Cleve: no candidates with last name 'Benedict' and first name 'Cleve'
# [fail-firstname] Case, Clifford P.: no candidates with last name 'Case' and first name 'Clifford, Cliff, Cliffy'
# [fail-firstname] Hansen, Clifford P.: no candidates with last name 'Hansen' and first name 'Clifford, Cliff, Cliffy'
# [fail-firstname] Allen, Clifford R.: no candidates with last name 'Allen' and first name 'Clifford, Cliff, Cliffy'
# [fail-firstname] Roberts, Clint: no candidates with last name 'Roberts' and first name 'Clint'
# [ambiguous] Mack, Connie: multiple candidates remain after deterministic filters:
#           name                             url
#    Connie Mack    /candidate/53281/connie-mack
# Connie Mack IV /candidate/53996/connie-mack-iv
# [ambiguous] Mack, Connie, III: multiple candidates remain after deterministic filters:
#           name                             url
#    Connie Mack    /candidate/53281/connie-mack
# Connie Mack IV /candidate/53996/connie-mack-iv
# [fail-firstname] Evans, Cooper: no candidates with last name 'Evans' and first name 'Cooper'
# [fail-firstname] Boggs, Corinne C. (Lindy): no candidates with last name 'Boggs' and first name 'Corinne'
# [fail-lastname] Hosmer, Craig: no candidates with last name 'Hosmer'
# [fail-firstname] James, Craig T.: no candidates with last name 'James' and first name 'Craig'
# [fail-firstname] Slaughter, D. French, Jr.: no candidates with last name 'Slaughter' and first name 'French'
# [fail-lastname] Milford, Dale: no candidates with last name 'Milford'
# [only-surname] Quayle, Dan: one candidate with last name 'Quayle' but firstname mismatch
#       name                          url
# Ben Quayle /candidate/123506/ben-quayle
# [ambiguous] Sullivan, Dan: multiple candidates remain after deterministic filters:
#                name                                   url
#        Dan Sullivan        /candidate/114964/dan-sullivan
# Daniel Sullivan III /candidate/208773/daniel-sullivan-iii
# [only-surname] Kuykendall, Dan H.: one candidate with last name 'Kuykendall' but firstname mismatch
#              name                               url
# Steven Kuykendall /candidate/8311/steven-kuykendall
# [only-surname] Mica, Daniel Andrew: one candidate with last name 'Mica' but firstname mismatch
#      name                        url
# John Mica /candidate/26805/john-mica
# [fail-firstname] Crane, Daniel B.: no candidates with last name 'Crane' and first name 'Dan, Daniel, Danny'
# [fail-firstname] Evans, Daniel J.: no candidates with last name 'Evans' and first name 'Dan, Daniel, Danny'
# [fail-firstname] Flood, Daniel J.: no candidates with last name 'Flood' and first name 'Dan, Daniel, Danny'
# [ambiguous] Davis, Danny K.: multiple candidates remain after deterministic filters:
#         name                            url
# Daniel Davis /candidate/101658/daniel-davis
#  Danny Davis     /candidate/233/danny-davis
# [fail-lastname] Fascell, Dante B.: no candidates with last name 'Fascell'
# [fail-lastname] Durenberger, Dave: no candidates with last name 'Durenberger'
# [ambiguous] Davis, David: multiple candidates remain after deterministic filters:
#        name                          url
# David Davis  /candidate/1496/david-davis
# David Davis /candidate/49070/david-davis
# David Davis /candidate/65005/david-davis
# David Davis   /candidate/753/david-davis
# [fail-lastname] Towell, David: no candidates with last name 'Towell'
# [ambiguous] Young, David: multiple candidates remain after deterministic filters:
#        name                           url
# David Young /candidate/155218/david-young
# David Young  /candidate/21134/david-young
# [fail-firstname] Stockman, David A.: no candidates with last name 'Stockman' and first name 'David, Dave'
# [fail-lastname] Marriott, David Daniel: no candidates with last name 'Marriott'
# [fail-lastname] Satterfield, David E., III: no candidates with last name 'Satterfield'
# [fail-firstname] Emery, David F.: no candidates with last name 'Emery' and first name 'David, Dave'
# [fail-firstname] Pryor, David H.: no candidates with last name 'Pryor' and first name 'David, Dave'
# [ambiguous] Taylor, David J.: multiple candidates remain after deterministic filters:
#                 name                                   url
#         David Taylor        /candidate/213920/david-taylor
# David Patrick Taylor /candidate/21947/david-patrick-taylor
# [fail-lastname] Karnes, David K.: no candidates with last name 'Karnes'
# [fail-firstname] Boren, David L.: no candidates with last name 'Boren' and first name 'David, Dave'
# [fail-lastname] Cornwell, David L.: no candidates with last name 'Cornwell'
# [fail-firstname] Sweeney, David McCann: no candidates with last name 'Sweeney' and first name 'David, Dave'
# [only-surname] Staton, David Michael: one candidate with last name 'Staton' but firstname mismatch
#        name                          url
# Paul Staton /candidate/49453/paul-staton
# [fail-firstname] Henderson, David N.: no candidates with last name 'Henderson' and first name 'David, Dave'
# [fail-firstname] Martin, David O'B.: no candidates with last name 'Martin' and first name 'David, Dave'
# [ambiguous] Joyce, David P.: multiple candidates remain after deterministic filters:
#        name                           url
# David Joyce /candidate/106431/david-joyce
#  Dave Joyce  /candidate/143052/dave-joyce
# [fail-firstname] Roe, David P.: no candidates with last name 'Roe' and first name 'David, Dave'
# [fail-lastname] Monson, David S.: no candidates with last name 'Monson'
# [fail-firstname] Martin, David T.: no candidates with last name 'Martin' and first name 'David, Dave'
# [fail-firstname] Dennis, David W.: no candidates with last name 'Dennis' and first name 'David, Dave'
# [fail-firstname] Evans, David W.: no candidates with last name 'Evans' and first name 'David, Dave'
# [fail-firstname] Mathis, Dawson: no candidates with last name 'Mathis' and first name 'Dawson'
# [only-surname] Haaland, Debra A.: one candidate with last name 'Haaland' but firstname mismatch
#        name                           url
# Deb Haaland /candidate/149368/deb-haaland
# [fail-firstname] Clawson, Del: no candidates with last name 'Clawson' and first name 'Del, Wendell'
# [only-surname] Latta, Delbert L.: one candidate with last name 'Latta' but firstname mismatch
#      name                       url
# Bob Latta /candidate/9926/bob-latta
# [fail-lastname] DeConcini, Dennis: no candidates with last name 'DeConcini'
# [fail-lastname] Eckart, Dennis E.: no candidates with last name 'Eckart'
# [fail-firstname] Hertel, Dennis M.: no candidates with last name 'Hertel' and first name 'Dennis'
# [fail-firstname] Smith, Denny: no candidates with last name 'Smith' and first name 'Denny'
# [fail-firstname] Bartlett, Dewey F.: no candidates with last name 'Bartlett' and first name 'Dewey'
# [fail-firstname] Cheney, Dick: no candidates with last name 'Cheney' and first name 'Dick, Richard'
# [fail-firstname] Clark, Dick: no candidates with last name 'Clark' and first name 'Dick, Richard'
# [fail-firstname] Nichols, Dick: no candidates with last name 'Nichols' and first name 'Dick, Richard'
# [fail-lastname] Shoup, Dick: no candidates with last name 'Shoup'
# [fail-firstname] Daniels, Dominick V.: no candidates with last name 'Daniels' and first name 'Dominick'
# [fail-lastname] Bonker, Don: no candidates with last name 'Bonker'
# [fail-lastname] Fuqua, Don: no candidates with last name 'Fuqua'
# [ambiguous] Johnson, Don: multiple candidates remain after deterministic filters:
#           name                             url
#    Don Johnson    /candidate/26819/don-johnson
# Donald Johnson /candidate/31286/donald-johnson
# [fail-lastname] Clausen, Don H.: no candidates with last name 'Clausen'
# [fail-firstname] Stewart, Donald: no candidates with last name 'Stewart' and first name 'Don, Donald, Donnie'
# [fail-firstname] Bailey, Donald A.: no candidates with last name 'Bailey' and first name 'Don, Donald, Donnie'
# [only-surname] Clancy, Donald D.: one candidate with last name 'Clancy' but firstname mismatch
#        name                           url
# Mike Clancy /candidate/206933/mike-clancy
# [only-surname] Lukens, Donald E.: one candidate with last name 'Lukens' but firstname mismatch
#           name                              url
# Charles Lukens /candidate/141290/charles-lukens
# [fail-lastname] Brotzman, Donald G.: no candidates with last name 'Brotzman'
# [ambiguous] Davis, Donald G.: multiple candidates remain after deterministic filters:
#                 name                                  url
#            Don Davis          /candidate/102950/don-davis
# Donald Spencer Davis /candidate/5966/donald-spencer-davis
# [fail-lastname] Albosta, Donald J.: no candidates with last name 'Albosta'
# [fail-firstname] Mitchell, Donald J.: no candidates with last name 'Mitchell' and first name 'Don, Donald, Donnie'
# [only-surname] Pease, Donald J.: one candidate with last name 'Pease' but firstname mismatch
#         name                         url
# Edward Pease /candidate/355/edward-pease
# [fail-firstname] Fraser, Donald M.: no candidates with last name 'Fraser' and first name 'Don, Donald, Donnie'
# [ambiguous] Payne, Donald M.: multiple candidates remain after deterministic filters:
#           name                           url
#   Donald Payne /candidate/26957/donald-payne
# Don Payne, Jr. /candidate/90668/don-payne-jr
# [fail-lastname] Riegle, Donald W., Jr.: no candidates with last name 'Riegle'
# [ambiguous] Jones, Doug: multiple candidates remain after deterministic filters:
#       name                          url
# Doug Jones  /candidate/15418/doug-jones
# Doug Jones /candidate/176464/doug-jones
# [fail-lastname] Walgren, Doug: no candidates with last name 'Walgren'
# [only-surname] Barnard, Doug, Jr.: one candidate with last name 'Barnard' but firstname mismatch
#                  name                                    url
# Andrew Barnard Carver /candidate/28616/andrew-barnard-carver
# [ambiguous] Applegate, Douglas: multiple candidates remain after deterministic filters:
#              name                                url
#    Doug Applegate   /candidate/169091/doug-applegate
# Douglas Applegate /candidate/27022/douglas-applegate
# [fail-lastname] Bosco, Douglas H.: no candidates with last name 'Bosco'
# [ambiguous] Hunter, Duncan: multiple candidates remain after deterministic filters:
#          name                             url
# Duncan Hunter /candidate/104308/duncan-hunter
# Duncan Hunter  /candidate/26776/duncan-hunter
# [ambiguous] Hunter, Duncan D.: multiple candidates remain after deterministic filters:
#          name                             url
# Duncan Hunter /candidate/104308/duncan-hunter
# Duncan Hunter  /candidate/26776/duncan-hunter
# [fail-lastname] Garn, E. J. (Jake): no candidates with last name 'Garn'
# [fail-firstname] Ruth, Earl B.: no candidates with last name 'Ruth' and first name 'Earl'
# [fail-lastname] Landgrebe, Earl F.: no candidates with last name 'Landgrebe'
# [fail-lastname] Bethune, Ed: no candidates with last name 'Bethune'
# [fail-firstname] Jones, Ed: no candidates with last name 'Jones' and first name 'Ed, Edolphus, Edward'
# [fail-firstname] Weber, Ed: no candidates with last name 'Weber' and first name 'Ed, Edolphus, Edward'
# [fail-firstname] Jenkins, Edgar L.: no candidates with last name 'Jenkins' and first name 'Edgar'
# [fail-firstname] Green, Edith: no candidates with last name 'Green' and first name 'Edith'
# [fail-lastname] Muskie, Edmund S.: no candidates with last name 'Muskie'
# [fail-firstname] Beard, Edward: no candidates with last name 'Beard' and first name 'Ed, Eddie, Edmund, Edward'
# [fail-firstname] Hutchinson, Edward: no candidates with last name 'Hutchinson' and first name 'Ed, Eddie, Edmund, Edward'
# [only-surname] Mezvinsky, Edward: one candidate with last name 'Mezvinsky' but firstname mismatch
#                         name                                           url
# Marjorie Margolies-Mezvinsky /candidate/27049/marjorie-margolies-mezvinsky
# [fail-firstname] Young, Edward: no candidates with last name 'Young' and first name 'Ed, Eddie, Edmund, Edward'
# [fail-lastname] Zorinsky, Edward: no candidates with last name 'Zorinsky'
# [only-surname] Kaufman, Edward E.: one candidate with last name 'Kaufman' but firstname mismatch
#        name                          url
# Joe Kaufman /candidate/17350/joe-kaufman
# [fail-lastname] Feighan, Edward F.: no candidates with last name 'Feighan'
# [fail-lastname] Biester, Edward G., Jr.: no candidates with last name 'Biester'
# [fail-lastname] Derwinski, Edward J.: no candidates with last name 'Derwinski'
# [fail-lastname] Gurney, Edward J.: no candidates with last name 'Gurney'
# [fail-lastname] Patten, Edward J.: no candidates with last name 'Patten'
# [fail-lastname] Stack, Edward J.: no candidates with last name 'Stack'
# [only-surname] Boland, Edward P.: one candidate with last name 'Boland' but firstname mismatch
#       name                          url
# Ray Boland /candidate/138626/ray-boland
# [only-surname] Madigan, Edward R.: one candidate with last name 'Madigan' but firstname mismatch
#            name                               url
# Michael Madigan /candidate/140445/michael-madigan
# [only-surname] Roybal, Edward R.: one candidate with last name 'Roybal' but firstname mismatch
#                  name                                    url
# Lucille Roybal-Allard /candidate/26766/lucille-roybal-allard
# [fail-lastname] Brooke, Edward W.: no candidates with last name 'Brooke'
# [fail-lastname] Pattison, Edward W.: no candidates with last name 'Pattison'
# [only-surname] Forsythe, Edwin B.: one candidate with last name 'Forsythe' but firstname mismatch
#           name                           url
# James Forsythe /candidate/688/james-forsythe
# [fail-lastname] Eshleman, Edwin D.: no candidates with last name 'Eshleman'
# [fail-lastname] Zschau, Edwin V. W.: no candidates with last name 'Zschau'
# [fail-lastname] Rudd, Eldon D.: no candidates with last name 'Rudd'
# [fail-lastname] Cederberg, Elford A.: no candidates with last name 'Cederberg'
# [fail-lastname] Holtzman, Elizabeth: no candidates with last name 'Holtzman'
# [only-surname] Grasso, Ella T.: one candidate with last name 'Grasso' but firstname mismatch
#        name                          url
# Lois Grasso /candidate/17151/lois-grasso
# [fail-lastname] Levitas, Elliott H.: no candidates with last name 'Levitas'
# [fail-lastname] Hillis, Elwood H.: no candidates with last name 'Hillis'
# [fail-lastname] Waldholtz, Enid Greene: no candidates with last name 'Waldholtz'
# [ambiguous] Crawford, Eric A. "Rick": multiple candidates remain after deterministic filters:
#          name                             url
# Rick Crawford /candidate/119208/rick-crawford
# Rick Crawford  /candidate/31538/rick-crawford
# [fail-lastname] Konnyu, Ernest L.: no candidates with last name 'Konnyu'
# [fail-firstname] Johnston, Eugene (Gene): no candidates with last name 'Johnston' and first name 'Eugene'
# [fail-lastname] Chappie, Eugene A.: no candidates with last name 'Chappie'
# [fail-firstname] Atkinson, Eugene V.: no candidates with last name 'Atkinson' and first name 'Eugene'
# [fail-firstname] Hebert, F. Edward: no candidates with last name 'Hebert' and first name 'Ed, Eddie, Edmund, Edward'
# [fail-firstname] St Germain, Fernand J.: no candidates with last name 'St Germain' and first name 'Fernand'
# [fail-lastname] Fithian, Floyd J.: no candidates with last name 'Fithian'
# [only-surname] Haskell, Floyd K.: one candidate with last name 'Haskell' but firstname mismatch
#         name                            url
# Kurt Haskell /candidate/139855/kurt-haskell
# [fail-firstname] Hicks, Floyd V.: no candidates with last name 'Hicks' and first name 'Floyd'
# [fail-lastname] Sunia, Foto I. F.: no candidates with last name 'Sunia'
# [only-surname] Annunzio, Frank: one candidate with last name 'Annunzio' but firstname mismatch
#           name                             url
# Tim D'Annunzio /candidate/117760/tim-dannunzio
# [fail-lastname] Brasco, Frank: no candidates with last name 'Brasco'
# [fail-lastname] Church, Frank: no candidates with last name 'Church'
# [fail-firstname] Harrison, Frank: no candidates with last name 'Harrison' and first name 'Frank, Francis'
# [fail-lastname] Stubblefield, Frank A.: no candidates with last name 'Stubblefield'
# [ambiguous] Lucas, Frank D.: multiple candidates remain after deterministic filters:
#        name                          url
# Frank Lucas  /candidate/1332/frank-lucas
# Frank Lucas /candidate/27032/frank-lucas
# [fail-lastname] Denholm, Frank E.: no candidates with last name 'Denholm'
# [fail-firstname] Evans, Frank E.: no candidates with last name 'Evans' and first name 'Frank, Francis'
# [fail-firstname] Moss, Frank E.: no candidates with last name 'Moss' and first name 'Frank, Francis'
# [only-surname] Guarini, Frank J.: one candidate with last name 'Guarini' but firstname mismatch
#         name                           url
# John Guarini /candidate/59969/john-guarini
# [fail-firstname] Horton, Frank J.: no candidates with last name 'Horton' and first name 'Frank, Francis'
# [fail-firstname] Clark, Frank M.: no candidates with last name 'Clark' and first name 'Frank, Francis'
# [ambiguous] Thompson, Fred: multiple candidates remain after deterministic filters:
#          name                             url
# Fred Thompson /candidate/117536/fred-thompson
# Fred Thompson  /candidate/22003/fred-thompson
# [fail-firstname] Rooney, Fred B.: no candidates with last name 'Rooney' and first name 'Fred'
# [fail-lastname] Eckert, Fred J.: no candidates with last name 'Eckert'
# [only-surname] Richmond, Frederick W.: one candidate with last name 'Richmond' but firstname mismatch
#            name                              url
# Cedric Richmond /candidate/35384/cedric-richmond
# [fail-firstname] Taylor, G.: no candidates with last name 'Taylor' (no usable tokens)
# [only-surname] Butterfield, G. K.: one candidate with last name 'Butterfield' but firstname mismatch
#                   name                                 url
# G. K. Butterfield, Jr. /candidate/41077/g-k-butterfield-jr
# [fail-firstname] Montgomery, G. V. (Sonny): no candidates with last name 'Montgomery' and first name 'Sonny'
# [fail-lastname] Whitehurst, G. William: no candidates with last name 'Whitehurst'
# [fail-firstname] McGee, Gale W.: no candidates with last name 'McGee' and first name 'Gale'
# [fail-lastname] Shriver, Garner E.: no candidates with last name 'Shriver'
# [fail-firstname] Brown, Garry E.: no candidates with last name 'Brown' and first name 'Garry'
# [fail-firstname] Myers, Gary A.: no candidates with last name 'Myers' and first name 'Gary'
# [fail-firstname] Hart, Gary W.: no candidates with last name 'Hart' and first name 'Gary'
# [fail-firstname] Nelson, Gaylord: no candidates with last name 'Nelson' and first name 'Gaylord'
# [only-surname] Aiken, George: one candidate with last name 'Aiken' but firstname mismatch
#       name                          url
# Clay Aiken /candidate/150323/clay-aiken
# [fail-firstname] McGovern, George: no candidates with last name 'McGovern' and first name 'George'
# [only-surname] Goodling, George A.: one candidate with last name 'Goodling' but firstname mismatch
#             name                               url
# William Goodling /candidate/27055/william-goodling
# [fail-lastname] Wortley, George C.: no candidates with last name 'Wortley'
# [fail-lastname] Danielson, George E.: no candidates with last name 'Danielson'
# [only-surname] Shipley, George E.: one candidate with last name 'Shipley' but firstname mismatch
#                 name                                   url
# Bob Shipley Auerbach /candidate/36230/bob-shipley-auerbach
# [fail-lastname] Mahon, George H.: no candidates with last name 'Mahon'
# [fail-firstname] Mitchell, George J.: no candidates with last name 'Mitchell' and first name 'George'
# [fail-lastname] Helmy, George S.: no candidates with last name 'Helmy'
# [fail-lastname] LeMieux, George S.: no candidates with last name 'LeMieux'
# [fail-firstname] Hansen, George V.: no candidates with last name 'Hansen' and first name 'George'
# [fail-firstname] Crockett, George W., Jr.: no candidates with last name 'Crockett' and first name 'George'
# [fail-firstname] Ford, Gerald R., Jr.: no candidates with last name 'Ford' and first name 'Gerry, Gerald'
# [fail-lastname] Ferraro, Geraldine A.: no candidates with last name 'Ferraro'
# [fail-lastname] Gude, Gilbert: no candidates with last name 'Gude'
# [fail-firstname] Long, Gillis W.: no candidates with last name 'Long' and first name 'Gillis'
# [fail-lastname] Spellman, Gladys Noon: no candidates with last name 'Spellman'
# [fail-firstname] Thompson, Glenn: no candidates with last name 'Thompson' and first name 'Glenn'
# [fail-firstname] Anderson, Glenn M.: no candidates with last name 'Anderson' and first name 'Glenn'
# [fail-firstname] Davis, Glenn R.: no candidates with last name 'Davis' and first name 'Glenn'
# [fail-firstname] Byron, Goodloe E.: no candidates with last name 'Byron' and first name 'Goodloe'
# [only-surname] Humphrey, Gordon J.: one candidate with last name 'Humphrey' but firstname mismatch
#            name                              url
# Vernon Humphrey /candidate/27789/vernon-humphrey
# [only-surname] Ganske, Greg: one candidate with last name 'Ganske' but firstname mismatch
#        name                          url
# John Ganske /candidate/21882/john-ganske
# [fail-firstname] Lopez, Greg: no candidates with last name 'Lopez' and first name 'Gregory, Greg'
# [fail-lastname] Carman, Gregory W.: no candidates with last name 'Carman'
# [fail-firstname] Savage, Gus: no candidates with last name 'Savage' and first name 'Gus, Augustus'
# [fail-lastname] Yatron, Gus: no candidates with last name 'Yatron'
# [only-surname] Molinari, Guy: one candidate with last name 'Molinari' but firstname mismatch
#           name                             url
# Susan Molinari /candidate/26977/susan-molinari
# [fail-lastname] Vander Jagt, Guy: no candidates with last name 'Vander Jagt'
# [fail-firstname] Gross, H. R.: no candidates with last name 'Gross' (no usable tokens)
# [fail-lastname] Daub, Hal: no candidates with last name 'Daub'
# [only-surname] Mathews, Harlan: one candidate with last name 'Mathews' but firstname mismatch
#          name                            url
# Peter Mathews /candidate/29305/peter-mathews
# [fail-firstname] Washington, Harold: no candidates with last name 'Washington' and first name 'Harold, Hal, Harry'
# [only-surname] Hollenbeck, Harold C.: one candidate with last name 'Hollenbeck' but firstname mismatch
#                name                                  url
# Lawrence Hollenbeck /candidate/37571/lawrence-hollenbeck
# [fail-firstname] Donohue, Harold D.: no candidates with last name 'Donohue' and first name 'Harold, Hal, Harry'
# [ambiguous] Ford, Harold E.: multiple candidates remain after deterministic filters:
#             name                             url
# Harold Ford, Jr.  /candidate/1003/harold-ford-jr
# Harold Ford, Sr. /candidate/27076/harold-ford-sr
# [fail-firstname] Hughes, Harold E.: no candidates with last name 'Hughes' and first name 'Harold, Hal, Harry'
# [fail-lastname] Runnels, Harold L.: no candidates with last name 'Runnels'
# [fail-firstname] Collier, Harold R.: no candidates with last name 'Collier' and first name 'Harold, Hal, Harry'
# [fail-firstname] Sawyer, Harold S.: no candidates with last name 'Sawyer' and first name 'Harold, Hal, Harry'
# [fail-lastname] Froehlich, Harold V.: no candidates with last name 'Froehlich'
# [fail-firstname] Williams, Harrison A., Jr.: no candidates with last name 'Williams' and first name 'Harrison'
# [fail-firstname] Schmitt, Harrison H.: no candidates with last name 'Schmitt' and first name 'Harrison'
# [fail-lastname] Meyner, Helen S.: no candidates with last name 'Meyner'
# [fail-lastname] Helstoski, Henry: no candidates with last name 'Helstoski'
# [only-surname] Nowak, Henry: one candidate with last name 'Nowak' but firstname mismatch
#          name                          url
# Patrick Nowak /candidate/516/patrick-nowak
# [fail-lastname] Bellmon, Henry L.: no candidates with last name 'Bellmon'
# [fail-firstname] Jackson, Henry M.: no candidates with last name 'Jackson' and first name 'Hank, Henry'
# [fail-firstname] Smith, Henry P., III: no candidates with last name 'Smith' and first name 'Hank, Henry'
# [fail-lastname] Reuss, Henry S.: no candidates with last name 'Reuss'
# [fail-firstname] Harris, Herbert E., II: no candidates with last name 'Harris' and first name 'Herbert, Herb'
# [fail-lastname] Badillo, Herman: no candidates with last name 'Badillo'
# [fail-lastname] Talmadge, Herman E.: no candidates with last name 'Talmadge'
# [fail-lastname] Schneebeli, Herman T.: no candidates with last name 'Schneebeli'
# [fail-firstname] Fong, Hiram L.: no candidates with last name 'Fong' and first name 'Hiram'
# [fail-lastname] Nielson, Howard C.: no candidates with last name 'Nielson'
# [fail-lastname] Wolpe, Howard E.: no candidates with last name 'Wolpe'
# [fail-firstname] Baker, Howard H., Jr.: no candidates with last name 'Baker' and first name 'Howard'
# [fail-lastname] Metzenbaum, Howard M.: no candidates with last name 'Metzenbaum'
# [fail-firstname] Cannon, Howard W.: no candidates with last name 'Cannon' and first name 'Howard'
# [fail-lastname] Robison, Howard W.: no candidates with last name 'Robison'
# [fail-lastname] Heflin, Howell: no candidates with last name 'Heflin'
# [only-surname] Humphrey, Hubert H.: one candidate with last name 'Humphrey' but firstname mismatch
#            name                              url
# Vernon Humphrey /candidate/27789/vernon-humphrey
# [fail-firstname] Scott, Hugh: no candidates with last name 'Scott' and first name 'Hugh'
# [fail-firstname] Carey, Hugh L.: no candidates with last name 'Carey' and first name 'Hugh'
# [fail-firstname] Andrews, Ike: no candidates with last name 'Andrews' and first name 'Ike'
# [fail-firstname] Johnston, J. Bennett: no candidates with last name 'Johnston' and first name 'Bennett'
# [fail-firstname] Hayworth, J. D.: no candidates with last name 'Hayworth' (no usable tokens)
# [fail-firstname] Vance, J. D.: no candidates with last name 'Vance' (no usable tokens)
# [fail-lastname] Roush, J. Edward: no candidates with last name 'Roush'
# [only-surname] Beall, J. Glenn, Jr.: one candidate with last name 'Beall' but firstname mismatch
#        name                          url
# Roger Beall /candidate/35530/roger-beall
# [fail-firstname] Burke, J. Herbert: no candidates with last name 'Burke' and first name 'Herbert, Herb'
# [only-surname] Pickle, J. J.: one candidate with last name 'Pickle' but firstname mismatch
#        name                        url
# J.J. Pickle /candidate/27086/jj-pickle
# [fail-lastname] Exon, J. James: no candidates with last name 'Exon'
# [fail-firstname] Robinson, J. Kenneth: no candidates with last name 'Robinson' and first name 'Kenneth'
# [only-surname] Correa, J. Luis: one candidate with last name 'Correa' but firstname mismatch
#       name                        url
# Lou Correa /candidate/9732/lou-correa
# [fail-firstname] Stanton, J. William: no candidates with last name 'Stanton' and first name 'William, Bill, Billy, Will, Bud'
# [fail-lastname] Brinkley, Jack: no candidates with last name 'Brinkley'
# [fail-lastname] Buechner, Jack: no candidates with last name 'Buechner'
# [ambiguous] Davis, Jack: multiple candidates remain after deterministic filters:
#       name                         url
# John Davis   /candidate/396/john-davis
# Jack Davis /candidate/45023/jack-davis
# [ambiguous] Edwards, Jack: multiple candidates remain after deterministic filters:
#             name                               url
#     John Edwards     /candidate/21107/john-edwards
# John Bel Edwards /candidate/66464/john-bel-edwards
# [fail-firstname] Kemp, Jack: no candidates with last name 'Kemp' and first name 'Jack, John'
# [fail-lastname] Hightower, Jack E.: no candidates with last name 'Hightower'
# [fail-lastname] Javits, Jacob K.: no candidates with last name 'Javits'
# [only-surname] LaTurner, Jake: one candidate with last name 'LaTurner' but firstname mismatch
#           name                              url
# Jacob LaTurner /candidate/107024/jacob-laturner
# [fail-lastname] Abdnor, James: no candidates with last name 'Abdnor'
# [fail-lastname] Abourezk, James: no candidates with last name 'Abourezk'
# [fail-firstname] Blanchard, James: no candidates with last name 'Blanchard' and first name 'Jimmie, Jimmy, Jimbo, James, Jim, Jamie'
# [fail-lastname] Fulbright, James: no candidates with last name 'Fulbright'
# [fail-firstname] Burke, James A.: no candidates with last name 'Burke' and first name 'Jimmie, Jimmy, Jimbo, James, Jim, Jamie'
# [only-surname] Haley, James A.: one candidate with last name 'Haley' but firstname mismatch
#           name                           url
# Theodore Haley /candidate/842/theodore-haley
# [ambiguous] Hayes, James A.: multiple candidates remain after deterministic filters:
#        name                           url
#   Jim Hayes     /candidate/1547/jim-hayes
# James Hayes /candidate/214744/james-hayes
# [fail-lastname] Mattox, James A.: no candidates with last name 'Mattox'
# [only-surname] McClure, James A.: one candidate with last name 'McClure' but firstname mismatch
#            name                               url
# Jessica McClure /candidate/178663/jessica-mcclure
# [fail-firstname] Allen, James B.: no candidates with last name 'Allen' and first name 'Jimmie, Jimmy, Jimbo, James, Jim, Jamie'
# [fail-firstname] Pearson, James B.: no candidates with last name 'Pearson' and first name 'Jimmie, Jimmy, Jimbo, James, Jim, Jamie'
# [fail-firstname] Cleveland, James C.: no candidates with last name 'Cleveland' and first name 'Jimmie, Jimmy, Jimbo, James, Jim, Jamie'
# [fail-lastname] Corman, James C.: no candidates with last name 'Corman'
# [ambiguous] Wright, James C., Jr.: multiple candidates remain after deterministic filters:
#         name                           url
# James Wright /candidate/25404/james-wright
# James Wright /candidate/49725/james-wright
# [fail-lastname] Santini, James D.: no candidates with last name 'Santini'
# [fail-firstname] Hastings, James F.: no candidates with last name 'Hastings' and first name 'Jimmie, Jimmy, Jimbo, James, Jim, Jamie'
# [fail-firstname] Lloyd, James F.: no candidates with last name 'Lloyd' and first name 'Jimmie, Jimmy, Jimbo, James, Jim, Jamie'
# [fail-firstname] McNulty, James F., Jr.: no candidates with last name 'McNulty' and first name 'Jimmie, Jimmy, Jimbo, James, Jim, Jamie'
# [fail-firstname] O'Hara, James G.: no candidates with last name 'O'Hara' and first name 'Jimmie, Jimmy, Jimbo, James, Jim, Jamie'
# [fail-lastname] Scheuer, James H.: no candidates with last name 'Scheuer'
# [fail-firstname] Weaver, James H.: no candidates with last name 'Weaver' and first name 'Jimmie, Jimmy, Jimbo, James, Jim, Jamie'
# [fail-firstname] Delaney, James J.: no candidates with last name 'Delaney' and first name 'Jimmie, Jimmy, Jimbo, James, Jim, Jamie'
# [fail-lastname] Florio, James J.: no candidates with last name 'Florio'
# [fail-firstname] Coyne, James K.: no candidates with last name 'Coyne' and first name 'Jimmie, Jimmy, Jimbo, James, Jim, Jamie'
# [fail-firstname] Buckley, James L.: no candidates with last name 'Buckley' and first name 'Jimmie, Jimmy, Jimbo, James, Jim, Jamie'
# [fail-lastname] Nelligan, James L.: no candidates with last name 'Nelligan'
# [fail-firstname] Collins, James M.: no candidates with last name 'Collins' and first name 'Jimmie, Jimmy, Jimbo, James, Jim, Jamie'
# ...
# [fail-lastname] Matsunaga, Spark M.: no candidates with last name 'Matsunaga'
# [fail-lastname] Parris, Stanford E. (Stan): no candidates with last name 'Parris'
# [fail-lastname] Lundine, Stanley N.: no candidates with last name 'Lundine'
# [fail-lastname] Solarz, Stephen J.: no candidates with last name 'Solarz'
# [only-surname] Pearce, Stevan: one candidate with last name 'Pearce' but firstname mismatch
#         name                           url
# Steve Pearce /candidate/10655/steve-pearce
# [fail-firstname] Bartlett, Steve: no candidates with last name 'Bartlett' and first name 'Steve, Steven, Stephen'
# [ambiguous] King, Steve: multiple candidates remain after deterministic filters:
#         name                            url
#   Steve King    /candidate/10853/steve-king
# Stephen King /candidate/216489/stephen-king
# [fail-lastname] Symms, Steven D.: no candidates with last name 'Symms'
# [fail-firstname] McKinney, Stewart B.: no candidates with last name 'McKinney' and first name 'Stewart'
# [fail-lastname] Symington, Stuart: no candidates with last name 'Symington'
# [ambiguous] Brooks, Susan W.: multiple candidates remain after deterministic filters:
#         name                            url
# Susan Brooks /candidate/135988/susan-brooks
# Susan Brooks    /candidate/180/susan-brooks
# [fail-firstname] Cox, TJ: no candidates with last name 'Cox' and first name 'Tj'
# [fail-firstname] Weiss, Ted: no candidates with last name 'Weiss' and first name 'Theodore, Ted'
# [fail-lastname] Guyer, Tennyson: no candidates with last name 'Guyer'
# [fail-lastname] Roncalio, Teno: no candidates with last name 'Roncalio'
# [fail-firstname] Bruce, Terry L.: no candidates with last name 'Bruce' and first name 'Terry, Terence'
# [fail-lastname] Dulski, Thaddeus J.: no candidates with last name 'Dulski'
# [fail-lastname] Risenhoover, Theodore M.: no candidates with last name 'Risenhoover'
# [only-surname] Tillis, Thomas: one candidate with last name 'Tillis' but firstname mismatch
#        name                          url
# Thom Tillis /candidate/57717/thom-tillis
# [fail-lastname] Luken, Thomas A.: no candidates with last name 'Luken'
# [fail-firstname] Evans, Thomas B., Jr.: no candidates with last name 'Evans' and first name 'Tom, Thomas, Tommy'
# [fail-firstname] Morgan, Thomas E.: no candidates with last name 'Morgan' and first name 'Tom, Thomas, Tommy'
# [fail-lastname] Eagleton, Thomas F.: no candidates with last name 'Eagleton'
# [fail-lastname] Railsback, Thomas F.: no candidates with last name 'Railsback'
# [only-surname] McIntyre, Thomas J.: one candidate with last name 'McIntyre' but firstname mismatch
#          name                          url
# Mike McIntyre /candidate/153/mike-mcintyre
# [fail-lastname] Tauke, Thomas Joseph: no candidates with last name 'Tauke'
# [only-surname] Ashley, Thomas L.: one candidate with last name 'Ashley' but firstname mismatch
#         name                          url
# Blake Ashley /candidate/1124/blake-ashley
# [ambiguous] Barrett, Thomas M.: multiple candidates remain after deterministic filters:
#        name                           url
# Tom Barrett /candidate/153540/tom-barrett
# Tom Barrett  /candidate/27138/tom-barrett
# [only-surname] Hagedorn, Thomas M.: one candidate with last name 'Hagedorn' but firstname mismatch
#         name                            url
# Jim Hagedorn /candidate/146027/jim-hagedorn
# [fail-firstname] Rees, Thomas M.: no candidates with last name 'Rees' and first name 'Tom, Thomas, Tommy'
# [ambiguous] Reynolds, Thomas M.: multiple candidates remain after deterministic filters:
#            name                             url
# Thomas Reynolds /candidate/4384/thomas-reynolds
#    Tom Reynolds     /candidate/632/tom-reynolds
# [fail-firstname] Downing, Thomas N.: no candidates with last name 'Downing' and first name 'Tom, Thomas, Tommy'
# [fail-lastname] Kindness, Thomas N.: no candidates with last name 'Kindness'
# [fail-firstname] O'Neill, Thomas P., Jr.: no candidates with last name 'O'Neill' and first name 'Tom, Thomas, Tommy'
# [ambiguous] Foley, Thomas S.: multiple candidates remain after deterministic filters:
#         name                           url
# Thomas Foley /candidate/27126/thomas-foley
#    Tom Foley    /candidate/54627/tom-foley
# [ambiguous] Griffin, Tim: multiple candidates remain after deterministic filters:
#            name                            url
#     Tim Griffin  /candidate/119213/tim-griffin
# Timothy Griffin /candidate/799/timothy-griffin
# [ambiguous] Johnson, Tim: multiple candidates remain after deterministic filters:
#            name                              url
# Timothy Johnson /candidate/27067/timothy-johnson
#     Tim Johnson     /candidate/51993/tim-johnson
#     Tim Johnson      /candidate/6338/tim-johnson
# [ambiguous] Ryan, Tim: multiple candidates remain after deterministic filters:
#         name                          url
# Timothy Ryan /candidate/2259/timothy-ryan
#     Tim Ryan    /candidate/45638/tim-ryan
# [fail-firstname] Hall, Tim L.: no candidates with last name 'Hall' and first name 'Tim, Timothy'
# [fail-firstname] Carter, Tim Lee: no candidates with last name 'Carter' and first name 'Tim, Timothy'
# [fail-firstname] Wirth, Timothy: no candidates with last name 'Wirth' and first name 'Timmy, Tim, Timothy'
# [ambiguous] Johnson, Timothy V.: multiple candidates remain after deterministic filters:
#            name                              url
# Timothy Johnson /candidate/27067/timothy-johnson
#     Tim Johnson     /candidate/51993/tim-johnson
#     Tim Johnson      /candidate/6338/tim-johnson
# [fail-firstname] Moffett, Toby: no candidates with last name 'Moffett' and first name 'Toby'
# [ambiguous] Barrett, Tom: multiple candidates remain after deterministic filters:
#        name                           url
# Tom Barrett /candidate/153540/tom-barrett
# Tom Barrett  /candidate/27138/tom-barrett
# [ambiguous] Campbell, Tom: multiple candidates remain after deterministic filters:
#            name                           url
#    Tom Campbell /candidate/48089/tom-campbell
# Thomas Campbell /candidate/71/thomas-campbell
# [ambiguous] Cole, Tom: multiple candidates remain after deterministic filters:
#        name                           url
# Thomas Cole /candidate/213578/thomas-cole
#    Tom Cole     /candidate/46034/tom-cole
# [only-surname] Corcoran, Tom: one candidate with last name 'Corcoran' but firstname mismatch
#                      name                                       url
# Joyce  Ann Jansa Corcoran /candidate/52711/joyce-ann-jansa-corcoran
# [only-surname] Loeffler, Tom: one candidate with last name 'Loeffler' but firstname mismatch
#           name                              url
# Kelly Loeffler /candidate/188718/kelly-loeffler
# [ambiguous] Reed, Tom: multiple candidates remain after deterministic filters:
#        name                           url
# Tom Reed II /candidate/127046/tom-reed-ii
#    Tom Reed     /candidate/25444/tom-reed
# [ambiguous] Sawyer, Tom: multiple candidates remain after deterministic filters:
#          name                            url
#    Tom Sawyer   /candidate/169323/tom-sawyer
# Thomas Sawyer /candidate/27019/thomas-sawyer
# [fail-lastname] Steed, Tom: no candidates with last name 'Steed'
# [fail-lastname] Gettys, Tom S.: no candidates with last name 'Gettys'
# [only-surname] Vandergriff, Tommy J.: one candidate with last name 'Vandergriff' but firstname mismatch
#              name                                url
# James Vandergriff /candidate/15309/james-vandergriff
# [fail-firstname] Macdonald, Torbert H.: no candidates with last name 'Macdonald' and first name 'Torbert'
# [fail-lastname] Gudger, V. Lamar: no candidates with last name 'Gudger'
# [fail-firstname] Hartke, Vance: no candidates with last name 'Hartke' and first name 'Vance'
# [only-surname] Ehlers, Vernon J.: one candidate with last name 'Ehlers' but firstname mismatch
#        name                          url
# Vern Ehlers /candidate/26907/vern-ehlers
# [fail-lastname] Thomson, Vernon W.: no candidates with last name 'Thomson'
# [only-surname] Fazio, Vic: one candidate with last name 'Fazio' but firstname mismatch
#         name                           url
# Victor Fazio /candidate/26731/victor-fazio
# [fail-lastname] Veysey, Victor V.: no candidates with last name 'Veysey'
# [fail-firstname] Weber, Vin: no candidates with last name 'Weber' and first name 'Vin'
# [only-surname] Snowbarger, Vince: one candidate with last name 'Snowbarger' but firstname mismatch
#               name                               url
# Vincent Snowbarger /candidate/545/vincent-snowbarger
# [fail-firstname] Smith, Virginia: no candidates with last name 'Smith' and first name 'Virginia'
# [only-surname] Hefner, W. G. (Bill): one candidate with last name 'Hefner' but firstname mismatch
#          name                            url
# Willie Hefner /candidate/27003/willie-hefner
# [fail-firstname] Moore, W. Henson: no candidates with last name 'Moore' and first name 'Henson'
# [fail-lastname] Poage, W. R.: no candidates with last name 'Poage'
# [fail-lastname] Stuckey, W. S. (Bill), Jr.: no candidates with last name 'Stuckey'
# [fail-firstname] Bennett, Wallace F.: no candidates with last name 'Bennett' and first name 'Wallace, Wally'
# [fail-firstname] Flowers, Walter: no candidates with last name 'Flowers' and first name 'Walter'
# [only-surname] Minnick, Walter: one candidate with last name 'Minnick' but firstname mismatch
#         name                         url
# Walt Minnick /candidate/436/walt-minnick
# [only-surname] Huddleston, Walter (Dee): one candidate with last name 'Huddleston' but firstname mismatch
#                       name                                       url
# Michael Francis Huddleston /candidate/840/michael-francis-huddleston
# [fail-lastname] Fauntroy, Walter E.: no candidates with last name 'Fauntroy'
# [fail-firstname] Powell, Walter E.: no candidates with last name 'Powell' and first name 'Walter'
# [fail-lastname] Rudman, Warren: no candidates with last name 'Rudman'
# [only-surname] Magnuson, Warren G.: one candidate with last name 'Magnuson' but firstname mismatch
#            name                               url
# Jaycee Magnuson /candidate/195747/jaycee-magnuson
# [fail-lastname] Dowdy, Wayne: no candidates with last name 'Dowdy'
# [fail-firstname] Hays, Wayne L.: no candidates with last name 'Hays' and first name 'Wayne'
# [fail-firstname] Grisham, Wayne R.: no candidates with last name 'Grisham' and first name 'Wayne'
# [fail-firstname] Bailey, Wendell: no candidates with last name 'Bailey' and first name 'Del, Wendell'
# [fail-firstname] Wyatt, Wendell: no candidates with last name 'Wyatt' and first name 'Del, Wendell'
# [fail-firstname] Anderson, Wendell R.: no candidates with last name 'Anderson' and first name 'Del, Wendell'
# [fail-firstname] Mills, Wilbur D.: no candidates with last name 'Mills' and first name 'Wilbur'
# [fail-lastname] Mayne, Wiley: no candidates with last name 'Mayne'
# [fail-lastname] Brodhead, William: no candidates with last name 'Brodhead'
# [fail-firstname] Carney, William: no candidates with last name 'Carney' and first name 'William, Bill, Billy, Will, Bud'
# [fail-firstname] Lehman, William: no candidates with last name 'Lehman' and first name 'William, Bill, Billy, Will, Bud'
# [fail-lastname] Proxmire, William: no candidates with last name 'Proxmire'
# [fail-lastname] Royer, William: no candidates with last name 'Royer'
# [fail-lastname] Steiger, William A.: no candidates with last name 'Steiger'
# [fail-lastname] Saxbe, William B.: no candidates with last name 'Saxbe'
# [fail-lastname] Widnall, William B.: no candidates with last name 'Widnall'
# [fail-lastname] Wampler, William C.: no candidates with last name 'Wampler'
# [only-surname] Hathaway, William D.: one candidate with last name 'Hathaway' but firstname mismatch
#               name                                  url
# Quintessa Hathaway /candidate/202465/quintessa-hathaway
# [fail-lastname] Dannemeyer, William E.: no candidates with last name 'Dannemeyer'
# [fail-lastname] Minshall, William E.: no candidates with last name 'Minshall'
# [fail-firstname] Walsh, William F.: no candidates with last name 'Walsh' and first name 'William, Bill, Billy, Will, Bud'
# [fail-firstname] Bray, William G.: no candidates with last name 'Bray' and first name 'William, Bill, Billy, Will, Bud'
# [fail-lastname] Boner, William H.: no candidates with last name 'Boner'
# [fail-lastname] Harsha, William H.: no candidates with last name 'Harsha'
# [fail-firstname] Gray, William H., III: no candidates with last name 'Gray' and first name 'William, Bill, Billy, Will, Bud'
# [fail-lastname] Hudnut, William H., III: no candidates with last name 'Hudnut'
# [ambiguous] Hughes, William J.: multiple candidates remain after deterministic filters:
#                name                                url
# William Hughes, Sr. /candidate/26950/william-hughes-sr
#    Bill Hughes, Jr.    /candidate/43293/bill-hughes-jr
# [ambiguous] Randall, William J.: multiple candidates remain after deterministic filters:
#              name                               url
# Bill Randall, Jr. /candidate/119342/bill-randall-jr
#   William Randall  /candidate/17309/william-randall
# [fail-lastname] Scherle, William J.: no candidates with last name 'Scherle'
# [only-surname] Dorn, William Jennings Bryan: one candidate with last name 'Dorn' but firstname mismatch
#        name                        url
# Debbie Dorn /candidate/500/debbie-dorn
# [fail-firstname] Armstrong, William L.: no candidates with last name 'Armstrong' and first name 'William, Bill, Billy, Will, Bud'
# [fail-firstname] Dickinson, William L.: no candidates with last name 'Dickinson' and first name 'William, Bill, Billy, Will, Bud'
# [fail-lastname] Hungate, William L.: no candidates with last name 'Hungate'
# [ambiguous] Owens, William L.: multiple candidates remain after deterministic filters:
#              name                                url
#        Bill Owens       /candidate/116354/bill-owens
# Bill Wesley Owens /candidate/21700/bill-wesley-owens
# [fail-firstname] Scott, William Lloyd: no candidates with last name 'Scott' and first name 'William, Bill, Billy, Will, Bud'
# [fail-firstname] Cowan, William M.: no candidates with last name 'Cowan' and first name 'William, Bill, Billy, Will, Bud'
# [fail-lastname] Ketchum, William M.: no candidates with last name 'Ketchum'
# [fail-lastname] Patman, William N.: no candidates with last name 'Patman'
# [fail-firstname] Mills, William O.: no candidates with last name 'Mills' and first name 'William, Bill, Billy, Will, Bud'
# [only-surname] Cotter, William R.: one candidate with last name 'Cotter' but firstname mismatch
#                name                                   url
# Missy Cotter Smasal /candidate/186718/missy-cotter-smasal
# [fail-lastname] Ratchford, William R.: no candidates with last name 'Ratchford'
# [fail-firstname] Roy, William R.: no candidates with last name 'Roy' and first name 'William, Bill, Billy, Will, Bud'
# [only-surname] Broomfield, William S.: one candidate with last name 'Broomfield' but firstname mismatch
#               name                                 url
# Charles Broomfield /candidate/39629/charles-broomfield
# [fail-firstname] Cohen, William S.: no candidates with last name 'Cohen' and first name 'William, Bill, Billy, Will, Bud'
# [fail-lastname] Mailliard, William S.: no candidates with last name 'Mailliard'
# [fail-firstname] Moorhead, William S.: no candidates with last name 'Moorhead' and first name 'William, Bill, Billy, Will, Bud'
# [fail-lastname] Cobey, William W.: no candidates with last name 'Cobey'
# [only-surname] Gradison, Willis D., Jr.: one candidate with last name 'Gradison' but firstname mismatch
#               name                              url
# Bill Gradison, Jr. /candidate/2406/bill-gradison-jr
# [fail-lastname] Mizell, Wilmer: no candidates with last name 'Mizell'
# [fail-lastname] Patman, Wright: no candidates with last name 'Patman'
# [fail-firstname] Burke, Yvonne B.: no candidates with last name 'Burke' and first name 'Yvonne'
# [fail-firstname] Nunn, Zachary: no candidates with last name 'Nunn' and first name 'Zachary, Zack'

# %%
print("Number of matched members:", mat.ref_name.nunique())
print("Number of unmatched members:", unmat.ref_name.nunique())
print("Frequency counts of reasons for non-matching:\n", unmat.match.value_counts())
# Out:
# Number of matched members: 1690
# Number of unmatched members: 904
# Frequency counts of reasons for non-matching:
#  match
# fail-lastname     327
# fail-firstname    323
# only-surname      151
# ambiguous         103
# Name: count, dtype: int64

# %%
ref["end_year"] = ref["end_year"].replace("Present", 9999)
ref["end_year"] = ref["end_year"].astype(int)
print("Number of members after 1992:", ref[ref.end_year>=1992].name.nunique())
# Out:
# Number of members after 1992: 1917
